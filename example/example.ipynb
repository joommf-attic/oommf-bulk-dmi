# %%
import os
import glob
import discretisedfield as df

# !tclsh $OOMMFTCL boxsi +fg example.mif

last_omf_file = max(glob.iglob("*.omf"), key=os.path.getctime)

field = df.read_oommf_file(last_omf_file)
# Out:
# Start: "/home/mb1a15/git/bulk_dmi_oommf/example/example.mif"
# Options: -threads 4
# Boxsi version 1.2.1.0
# Running on: kanta
# OS/machine: Linux/x86_64
# User: mb1a15	PID: 17292
# Number of threads: 4
# Mesh geometry: 40 x 40 x 8 = 12 800 cells
# Checkpoint file: /home/mb1a15/git/bulk_dmi_oommf/example/Syrmion_D=4..restart
# Boxsi run end.

# %%
# %matplotlib inline
field.plot_slice('z', 0);
